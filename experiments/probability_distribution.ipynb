# %%
import scipy.stats as stats

from my_stats.probability_distribution import plot_distribution

# %% [markdown]
# # Discrete Probability Distribution

# %% [markdown]
# ## Binominal Distribution

# %%
rv = stats.binom(n=10, p=0.5)
plot_distribution(rv, title="Binomial Distribution")

# %% [markdown]
# # Continual Probability Distribution

# %% [markdown]
# ## Normal Distribution

# %%
rv = stats.norm(loc=0, scale=1)
plot_distribution(rv, title="Standard Normal Distribution")

# %% [markdown]
# ## Parato Distribution

# %%
rv = stats.pareto(b=1)
plot_distribution(rv, title="Pareto Distribution")
# Out:
# /Users/kayanokeita/workspace/statistics/src/my_stats/probability_distribution.py:81: RuntimeWarning: invalid value encountered in subtract
#   data.mean - data.std, color="green", linestyle="--", label="Mean ± 1 Std"

# %%
rv = stats.pareto(b=2)
plot_distribution(rv, title="Pareto Distribution")

# %%
rv = stats.pareto(b=5)
plot_distribution(rv, title="Pareto Distribution")

# %%
rv = stats.pareto(b=10)
plot_distribution(rv, title="Pareto Distribution")

# %% [markdown]
# ## Laplace distribution(double exponential distribution)

# %%
rv = stats.laplace()
plot_distribution(rv, title="Laplace Distribution")
